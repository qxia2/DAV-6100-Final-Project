# %% [markdown]
# NYC Rolling Sales Data last 12 months (October 2018-October 2019) <br>
# Data Dictionary: https://www1.nyc.gov/assets/finance/downloads/pdf/07pdf/glossary_rsf071607.pdf

# %%
import pandas as pd

# %%
# Test the import of data from NYC Rolling Sales Data by importing
# the Manhattan data
# skip the first 4 rows as they contain information about the file
manhattan = pd.read_excel('https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_manhattan.xls', skiprows = 4)

# %%
# see the first 5 rows of the Manhattan dataframe
manhattan.head()
# Out:
#    BOROUGH   NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT  \
# 0        1  ALPHABET CITY  01 ONE FAMILY DWELLINGS                    1
# 1        1  ALPHABET CITY  01 ONE FAMILY DWELLINGS                    1
# 2        1  ALPHABET CITY  01 ONE FAMILY DWELLINGS                    1
# 3        1  ALPHABET CITY  02 TWO FAMILY DWELLINGS                    1
# 4        1  ALPHABET CITY  02 TWO FAMILY DWELLINGS                    1
#
#    BLOCK  LOT  EASE-MENT BUILDING CLASS AT PRESENT              ADDRESS  \
# 0    376   43        NaN                        S1  743 EAST 6TH STREET
# 1    390   61        NaN                        A4  189 EAST 7TH STREET
# 2    400   19        NaN                        A4  526 EAST 5TH STREET
# 3    404    1        NaN                        B9         166 AVENUE A
# 4    404    1        NaN                        B9         166 AVENUE A
#
#   APARTMENT NUMBER  ...  RESIDENTIAL UNITS  COMMERCIAL UNITS  TOTAL UNITS  \
# ...

# %%
# Import the excel data for each of the other 4 boroughs into Pandas Dataframes
bronx = pd.read_excel('https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_bronx.xls', skiprows = 4)
brooklyn = pd.read_excel('https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_brooklyn.xls', skiprows = 4)
queens = pd.read_excel('https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_queens.xls', skiprows = 4)
statenisland = pd.read_excel('https://www1.nyc.gov/assets/finance/downloads/pdf/rolling_sales/rollingsales_statenisland.xls', skiprows = 4)

# %%
#Combine all the dataframes for each borough into one dataframe 
#for all of NYC 
nyc = pd.concat([manhattan,bronx,brooklyn,queens,statenisland])

# %%
# See how many listings there are for each borough
nyc['BOROUGH'].value_counts()
# Out:
# 4    25479
# 3    23210
# 1    17751
# 2     7647
# 5     7568
# Name: BOROUGH, dtype: int64

# %%
# Get summary of the numerical information
# Notice that borough is included as it is considered numerical (needs to be changed to actual values)
nyc.describe()
# Out:
#             BOROUGH         BLOCK           LOT  EASE-MENT      ZIP CODE  \
# count  81655.000000  81655.000000  81655.000000        0.0  79342.000000
# mean       2.968967   4363.533390    373.759721        NaN  10851.936830
# std        1.282588   3678.763414    651.592703        NaN    564.054812
# min        1.000000      1.000000      1.000000        NaN  10001.000000
# 25%        2.000000   1323.000000     22.000000        NaN  10306.000000
# 50%        3.000000   3386.000000     50.000000        NaN  11209.000000
# 75%        4.000000   6546.000000   1001.000000        NaN  11358.000000
# max        5.000000  16350.000000   9109.000000        NaN  11697.000000
#
#        RESIDENTIAL UNITS  COMMERCIAL UNITS   TOTAL UNITS  LAND SQUARE FEET  \
# count       81655.000000      81655.000000  81655.000000      8.165500e+04
# mean            1.550609          0.189113      1.739722      2.339326e+03
# std             9.884473          4.508176     10.965856      1.432546e+04
# ...

# %% [markdown]
# Data is available at the level of what was sold - either a whole building or an individual apartment.
# Borough needs to be changed to reflect the name of the borough, and not the numerical code.
#
# Questions for future:
# 1. How should this data be updated?
# 2. How to handle SALE PRICE of 0? According to the data dictionary, it might mean that property was inherited. It doesn't appear to be a sale, in which case it should be omitted.
