# %%
import pandas as pd

# %%
sales_listings = pd.read_csv('http://files.zillowstatic.com/research/public/Zip/MedianDailyListings_NSA_AllHomes_Zip.csv')

# %%
sales_listings.head()
# Out:
#    SizeRank  RegionID  RegionName RegionType StateName  2013-01  2013-02  \
# 0       1.0     61639       10025        Zip        NY    222.0    234.0
# 1       2.0     84654       60657        Zip        IL    288.0    306.0
# 2       3.0     61637       10023        Zip        NY    330.0    321.0
# 3       4.0     91982       77494        Zip        TX    611.0    656.0
# 4       5.0     84616       60614        Zip        IL    357.0    374.0
#
#    2013-03  2013-04  2013-05  ...  2018-12  2019-01  2019-02  2019-03  \
# 0    235.0    266.0    259.0  ...    190.0    177.0    188.0    228.0
# 1    370.0    384.0    396.0  ...    301.0    289.0    330.0    352.0
# 2    324.0    362.0    377.0  ...    410.0    386.0    392.0    398.0
# 3    694.0    666.0    675.0  ...    657.0    618.0    656.0    705.0
# 4    400.0    398.0    422.0  ...    423.0    382.0    470.0    538.0
#
#    2019-04  2019-05  2019-06  2019-07  2019-08  2019-09
# ...

# %%
zillow_median_price = pd.read_csv('http://files.zillowstatic.com/research/public/Zip/Sale_Prices_Zip.csv')

# %%
zillow_median_price['StateName'].value_counts()
# Out:
# California              785
# Florida                 553
# New York                235
# Pennsylvania            225
# Illinois                224
# Michigan                220
# Ohio                    210
# New Jersey              206
# Washington              203
# Virginia                192
# North Carolina          182
# Massachusetts           178
# Colorado                175
# Arizona                 171
# Georgia                 170
# Maryland                147
# Tennessee               142
# Minnesota               131
# Oregon                  124
# Texas                   119
# Wisconsin                91
# Missouri                 89
# South Carolina           89
# Nevada                   70
# Louisiana                70
# Alabama                  69
# Connecticut              68
# Kentucky                 68
# Indiana                  66
# Utah                     53
# Oklahoma                 52
# Arkansas                 46
# Kansas                   46
# ...

# %%
zillow_ny_median_home_sale_price = zillow_median_price[zillow_median_price['StateName'] == 'New York']

# %%
zillow_ny_median_home_sale_price.describe()
# Out:
#            RegionID    RegionName     SizeRank        2008-03        2008-04  \
# count    235.000000    235.000000   235.000000      53.000000      53.000000
# mean   62567.744681  12325.387234  3238.119149  292941.509434  293709.433962
# std      648.683205   1414.537072  1615.988563  148995.987858  154438.691177
# min    61616.000000  10002.000000     1.000000   77300.000000   74700.000000
# 25%    62144.000000  11551.000000  2016.500000  164500.000000  167200.000000
# 50%    62262.000000  11790.000000  3468.000000  299400.000000  283600.000000
# 75%    63297.500000  13790.000000  4555.500000  397000.000000  397000.000000
# max    63776.000000  14850.000000  5678.000000  760200.000000  792200.000000
#
#              2008-05        2008-06        2008-07        2008-08  \
# count      53.000000      53.000000      53.000000      53.000000
# mean   289998.113208  285977.358491  285190.566038  282437.735849
# std    149463.754920  143057.517536  141077.428637  142021.289339
# ...
